# %% [markdown]
# ## Tutorial Objectives:
# In this Tutorial we will cover some ways we can create any array in Numpy. Numpy's core functionality includes its ability to create arrays of ndimensions. By the end of this tutorial you will:
#
# 1. Learn How to Convert Python Sequences to Numpy Arrays
# 2. Intrinsic Numpy Array Creation Functions
# 3. General Ndarray Creation Functions
# 4. Replicating Or Joining  Mutating existing Arrays

# %%
import numpy as np

# %% [markdown]
# # Introduction
#
# There are 6 ways of creating numpy arrays:
#
# 1. Conversion from other Python Datastructures
# 2. Instrinct Numpy array creation.
# 3. Replicating , joining or mutating existing arrays
# 4. Reading arrays from disk either standard or custom formats.
# 5. Creating arrays from raw bytes through the use of strings or buffers.
# 6. Use of special libraries

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.5.1
